# %%
import pandas as pd 
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
obj1
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj1.iloc[0]
# Out:
# 35000

# %%
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj2
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
obj3 = pd.isnull(obj2)
obj3
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
x = obj2['California']
obj2['California'] != x
# Out:
# True

# %%
pd.isna(obj2['California'])
# Out:
# True

# %%
import math
math.isnan(obj2['California'])
# Out:
# True

# %%
obj3['California'] == None
# Out:
# False

# %%
d = {'1': 'Alice','2': 'Bob','3': 'Rita','4': 'Molly','5': 'Ryan'}
S = pd.Series(d)
S
# Out:
# 1    Alice
# 2      Bob
# 3     Rita
# 4    Molly
# 5     Ryan
# dtype: object

# %%
S.iloc[0:3]
# Out:
# 1    Alice
# 2      Bob
# 3     Rita
# dtype: object

# %%
import pandas as pd 
df = pd.read_csv('/content/class_grades.csv')
df.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
df1=df.rename(mapper=lambda x: x.upper(), axis='columns')
df1.head()
# Out:
#    PREFIX  ASSIGNMENT  TUTORIAL  MIDTERM  TAKEHOME  FINAL
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
# Out:
#     PREFIX  ASSIGNMENT  TUTORIAL  MIDTERM  TAKEHOME  FINAL
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17      NaN     63.15  48.89
# 3        7         NaN       NaN    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8         NaN    103.71    45.00     93.52  61.94
# 95       7         NaN     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
df = pd.read_csv('/content/Admission_Predict.csv', index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df = df.loc[:, ['GRE Score', 'TOEFL Score']]
df.head()
# Out:
#             GRE Score  TOEFL Score
# Serial No.
# 1                 337          118
# 2                 324          107
# 3                 316          104
# 4                 322          110
# 5                 314          103

# %%
df[df['TOEFL Score'] > 105].head()
# Out:
#             GRE Score  TOEFL Score
# Serial No.
# 1                 337          118
# 2                 324          107
# 4                 322          110
# 6                 330          115
# 7                 321          109

# %%
df.where(df['TOEFL Score'] > 105).dropna().head()
# Out:
#             GRE Score  TOEFL Score
# Serial No.
# 1               337.0        118.0
# 2               324.0        107.0
# 4               322.0        110.0
# 6               330.0        115.0
# 7               321.0        109.0

# %%
df = pd.read_csv('/content/Admission_Predict.csv', index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
df.columns = [x.lower().strip() for x in df.columns]
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %%
df = df[['gre score', 'toefl score']]
df.head()
# Out:
#             gre score  toefl score
# Serial No.
# 1                 337          118
# 2                 324          107
# 3                 316          104
# 4                 322          110
# 5                 314          103

# %%
array_2d = pd.array([[400, 200], [337, 118], [324, 107]])

# %%
array_2d
# Out:
# <PandasArray>
# [['gre score', 'toefl score'], [337, 118], [324, 107]]
# Length: 3, dtype: object

# %%
array_2d[0][1]
# Out:
# 'toefl score'

# %%
df = pd.DataFrame(array_2d)
df
# Out:
#      0    1
# 0  400  200
# 1  337  118
# 2  324  107

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
df.columns = ['gre score', 'toefl score']

# %%
df
# Out:
#    gre score  toefl score
# 0        400          200
# 1        337          118
# 2        324          107

# %%
index_cty = ['Ohio', 'Colorado', 'Utah', 'New York']
data = {'one': [0, 4, 8, 12], 'two':[1, 5, 9, 13], 'three': [3, 6, 10, 14], 
        'four': [3, 7, 11, 15]}
data
# Out:
# {'four': [3, 7, 11, 15],
#  'one': [0, 4, 8, 12],
#  'three': [3, 6, 10, 14],
#  'two': [1, 5, 9, 13]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    one  two  three  four
# 0    0    1      3     3
# 1    4    5      6     7
# 2    8    9     10    11
# 3   12   13     14    15

# %%
df.set_index(index_cty)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-e1605f821ad4> in <module>()
# ----> 1 df.set_index(index_cty)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['Ohio', 'Colorado', 'Utah', 'New York'] are in the columns"

# %%
data = {'Ohio': [0, 1, 3, 4], 'Colorado': [4, 5, 6, 7], 'Utah': [8, 9, 10, 11], 
        'New York': [12, 13, 14, 15]}
data
# Out:
# {'Colorado': [4, 5, 6, 7],
#  'New York': [12, 13, 14, 15],
#  'Ohio': [0, 1, 3, 4],
#  'Utah': [8, 9, 10, 11]}

# %%
df = pd.DataFrame.from_dict(data, orient='index', columns=['one', 'two', 'three', 'four'])
df
# Out:
#           one  two  three  four
# Ohio        0    1      3     4
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
df1 = df
df1.drop('Ohio')
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
# Out:
#           one  two  three  four
# Ohio        0    1      3     4
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
df1.drop('one', axis=1)
# Out:
#           two  three  four
# Ohio        1      3     4
# Colorado    5      6     7
# Utah        9     10    11
# New York   13     14    15

# %%
df1
# Out:
#           one  two  three  four
# Ohio        0    1      3     4
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
df.drop(['Utah', 'Colorado'])
# Out:
#           one  two  three  four
# Ohio        0    1      3     4
# New York   12   13     14    15

# %%
s1 = pd.Series({1: 'Alice', 2: 'Jack', 3: 'Molly'})
s2 = pd.Series({'Alice': 1, 'Jack': 2, 'Molly': 3})

# %%
s1
# Out:
# 1    Alice
# 2     Jack
# 3    Molly
# dtype: object

# %%
s2
# Out:
# Alice    1
# Jack     2
# Molly    3
# dtype: int64

# %%
s2[1]
# Out:
# 2

# %%
s2.iloc[1]
# Out:
# 2

# %%
s1.loc[1]
# Out:
# 'Alice'

# %%
s1.append(s2)
# Out:
# 1        Alice
# 2         Jack
# 3        Molly
# Alice        1
# Jack         2
# Molly        3
# dtype: object

# %%
s2 = pd.Series({'Alice': 1, 'Jack': 2, 'Molly': 3, 'Tya': 4, 'Tya': 100, 'Tya': 5})

# %%
s2
# Out:
# Alice    1
# Jack     2
# Molly    3
# Tya      5
# dtype: int64

# %%
for x in s2.iteritems():
  print(x)
# Out:
# ('Alice', 1)
# ('Jack', 2)
# ('Molly', 3)
# ('Tya', 5)

# %%
df = pd.read_csv('/content/Admission_Predict.csv', index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
df.columns = [x.lower().strip() for x in df.columns]
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %%
df = df[['gre score', 'toefl score']]
df.head()
# Out:
#             gre score  toefl score
# Serial No.
# 1                 337          118
# 2                 324          107
# 3                 316          104
# 4                 322          110
# 5                 314          103

# %%
df[(df['toefl score']>105)&(df['toefl score']<115)].head()
# Out:
#             gre score  toefl score
# Serial No.
# 2                 324          107
# 4                 322          110
# 7                 321          109
# 10                323          108
# 11                325          106

# %%
df[df['toefl score'].gt(105)&df['toefl score'].lt(115)].head()
# Out:
#             gre score  toefl score
# Serial No.
# 2                 324          107
# 4                 322          110
# 7                 321          109
# 10                323          108
# 11                325          106

# %%
df[df['toefl score'].isin(range(106,115))].head()
# Out:
#             gre score  toefl score
# Serial No.
# 2                 324          107
# 4                 322          110
# 7                 321          109
# 10                323          108
# 11                325          106

# %%
students = [{'Name': 'Alice',
             'Age': 20,
             'Gender': 'F'},
            {'Name': 'Jack',
             'Age': 22,
             'Gender': 'M'}]
students
# Out:
# [{'Age': 20, 'Gender': 'F', 'Name': 'Alice'},
#  {'Age': 22, 'Gender': 'M', 'Name': 'Jack'}]

# %%
df = pd.DataFrame(students, index=['Mathematics', 'Sociology'])
df
# Out:
#               Name  Age Gender
# Mathematics  Alice   20      F
# Sociology     Jack   22      M

# %%
df.T['Mathematics']
# Out:
# Name      Alice
# Age          20
# Gender        F
# Name: Mathematics, dtype: object

# %%
df.loc['Mathematics']
# Out:
# Name      Alice
# Age          20
# Gender        F
# Name: Mathematics, dtype: object
